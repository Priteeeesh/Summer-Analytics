# %%
import pandas as pd
import numpy as np

# %%
testset=pd.read_csv('test.csv')
trainset=pd.read_csv('train.csv')
ss=pd.read_csv('Sample_submission.csv')

testset = testset.drop('EmployeeNumber', axis = 1)
trainset = trainset.drop('EmployeeNumber', axis = 1)
trainset.head(20)

from sklearn.preprocessing import LabelEncoder

for column in testset.columns:
        if testset[column].dtype == np.number:
            continue
        testset[column] = LabelEncoder().fit_transform(testset[column])
for column in trainset.columns:
        if trainset[column].dtype == np.number:
            continue
        trainset[column] = LabelEncoder().fit_transform(trainset[column])

# %%
xtest=testset
ytrain=trainset['Attrition']
xtrain=trainset.drop('Attrition',axis = 1)
from sklearn.linear_model import LogisticRegression  
Lr=LogisticRegression(solver='lbfgs',max_iter=5000,C=0.5,penalty='l2',random_state=1)
Lr.fit(xtrain,ytrain)
a=Lr.predict_proba(xtest)
b=a[:,1]
ss=ss.drop('Attrition',axis=1)
ss['Attrition']=b
ss.to_csv('submissionnewest.csv',index=False)

# %%
object_cols = [col for col in trainset.columns if trainset[col].dtype == "object"]

# %%
df = pd.get_dummies(trainset, prefix_sep=" ",columns=object_cols)

# %%
# Out:
#         Id  Age  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0        0   12          0               0           1                 1
# 1        1   18          0               2           1                11
# 2        2   37          1               2           2                 1
# 3        3   21          0               2           1                23
# 4        4   19          0               2           1                 2
# ...    ...  ...        ...             ...         ...               ...
# 1623  1623   24          1               1           1                18
# 1624  1624   37          1               2           2                 1
# 1625  1625    7          1               2           2                 8
# 1626  1626   11          1               2           0                12
# 1627  1627   11          1               2           1                17
#
#       Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0             2               3                        2       0  ...
# 1             3               1                        2       0  ...
# 2             0               3                        2       1  ...
# 3             0               1                        0       1  ...
# 4             2               4                        2       1  ...
# ...         ...             ...                      ...     ...  ...
# 1623          2               3                        2       1  ...
# 1624          0               3                        2       1  ...
# 1625          1               1                        0       1  ...
# 1626          2               0                        0       1  ...
# 1627          0               3                        2       1  ...
#
#       PerformanceRating  StockOptionLevel  TotalWorkingYears  \
# 0                     0                 0                 12
# 1                     0                 2                  7
# 2                     0                 0                 12
# 3                     0                 0                 18
# 4                     0                 1                 10
# ...                 ...               ...                ...
# 1623                  0                 0                  7
# 1624                  0                 0                 12
# 1625                  0                 0                  6
# 1626                  0                 3                  4
# 1627                  0                 0                  4
#
#       TrainingTimesLastYear  YearsAtCompany  YearsInCurrentRole  \
# 0                         2              11                   7
# 1                         2               3                   2
# 2                         3               9                   7
# 3                         2               7                   7
# 4                         2              10                   7
# ...                     ...             ...                 ...
# 1623                      2               2                   2
# 1624                      3               9                   7
# 1625                      2               3                   2
# 1626                      3               2                   2
# 1627                      3               4                   3
#
#       YearsSinceLastPromotion  YearsWithCurrManager  CommunicationSkill  \
# 0                           6                     7                   3
# 1                           1                     1                   1
# 2                           7                     3                   4
# 3                           1                     7                   3
# 4                           7                     8                   0
# ...                       ...                   ...                 ...
# 1623                        2                     2                   2
# 1624                        7                     3                   4
# 1625                        2                     2                   4
# 1626                        2                     0                   4
# 1627                        0                     1                   1
#
#       Behaviour
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 1623          0
# 1624          0
# 1625          0
# 1626          0
# 1627          0
#
# [1628 rows x 28 columns]
